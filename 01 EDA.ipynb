# %%
import pandas as pd
import numpy as np
import yfinance as yf
import plotly.graph_objects as go
import random

# %%
df = yf.download('SPY', start='2000-01-01')
df
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2000-01-03  148.250000  148.250000  143.875000  145.437500   93.881950
# 2000-01-04  143.531250  144.062500  139.640625  139.750000   90.210556
# 2000-01-05  139.937500  141.531250  137.250000  140.000000   90.371933
# 2000-01-06  139.625000  141.500000  137.750000  137.750000   88.919563
# 2000-01-07  140.312500  145.750000  140.062500  145.750000   94.083687
# ...                ...         ...         ...         ...         ...
# 2023-12-22  473.859985  475.380005  471.700012  473.649994  473.649994
# 2023-12-26  474.070007  476.579987  473.989990  475.649994  475.649994
# 2023-12-27  475.440002  476.660004  474.890015  476.510010  476.510010
# 2023-12-28  476.880005  477.549988  476.260010  476.690002  476.690002
# 2023-12-29  476.489990  477.029999  473.299988  475.309998  475.309998
#
#                Volume
# Date
# 2000-01-03    8164300
# 2000-01-04    8089800
# 2000-01-05   12177900
# 2000-01-06    6227200
# 2000-01-07    8066500
# ...               ...
# 2023-12-22   67126600
# 2023-12-26   55387000
# 2023-12-27   68000300
# 2023-12-28   77158100
# 2023-12-29  122234100
#
# [6037 rows x 6 columns]

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=df.index, y=df['Adj Close'], name='Adj Close'))
fig.show()

# %%
logreturns = np.log(df['Adj Close']).diff().dropna()
fig = go.Figure()
fig.add_trace(go.Scatter(x=logreturns.index, y=logreturns, name='Log-Returns'))
fig.show()

# %% [markdown]
# # Check for Stationarity

# %%
from statsmodels.tsa.stattools import adfuller

# %%
def adf_test(series):
    print ('Results of Dickey-Fuller Test:')
    dftest = adfuller(series, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print (dfoutput)
# Call the function and run the test

adf_test(logreturns)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -19.282110
# p-value                           0.000000
# #Lags Used                       15.000000
# Number of Observations Used    6020.000000
# Critical Value (1%)              -3.431437
# Critical Value (5%)              -2.862020
# Critical Value (10%)             -2.567026
# dtype: float64

# %%
logreturns = np.array(np.log(df['Adj Close']).diff().dropna())

# %%
logreturns.shape
# Out:
# (6036,)
